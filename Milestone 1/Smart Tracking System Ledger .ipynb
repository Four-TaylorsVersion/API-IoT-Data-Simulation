# %%
import pandas as pd


# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("smart_environment_data_Official.csv")


# Display the first few rows
print(df.head())
# Out:
#           timestamp sensor_id     co2_ppm  pm25_ugm3  temperature_c  \
# 0   07/05/2025 4:14   SENS762  433.043819  35.411776           30.7
# 1  06/05/2025 23:48   SENS414  378.758719  19.912831           34.1
# 2  06/05/2025 13:46   SENS874  411.669284  39.356963           31.2
# 3   07/05/2025 2:09   SENS903  475.838638  29.126293           28.7
# 4   06/05/2025 8:35   SENS114  396.233177  40.948456           32.0
#
#    humidity_percent  soil_moisture_percent  water_ph  turbidity_ntu
# 0              64.6                   28.8      6.88           1.82
# 1              83.7                   29.3      8.18           4.00
# 2              85.1                   22.7      6.89           1.34
# 3              76.8                   15.6      7.85           1.13
# 4              81.7                   27.9      7.73           0.04

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0x1549608d05D5484c8e323a79d721c84EDb92b801"


# ABI from Remix
abi = [
    {
        "inputs": [],
        "stateMutability": "nonpayable",
        "type": "constructor"
    },
    {
        "anonymous": False,
        "inputs": [
            {"indexed": False, "internalType": "uint256", "name": "timestamp", "type": "uint256"},
            {"indexed": False, "internalType": "string", "name": "sensorId", "type": "string"},
            {"indexed": False, "internalType": "string", "name": "MetricType", "type": "string"},
            {"indexed": False, "internalType": "string", "name": "MetricValue", "type": "string"}
        ],
        "name": "DataStored",
        "type": "event"
    },
    {
        "inputs": [],
        "name": "MAX_ENTRIES",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "name": "dataRecords",
        "outputs": [
            {"internalType": "uint256", "name": "timestamp", "type": "uint256"},
            {"internalType": "string", "name": "sensorId", "type": "string"},
            {"internalType": "string", "name": "MetricType", "type": "string"},
            {"internalType": "string", "name": "MetricValue", "type": "string"}
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [{"internalType": "uint256", "name": "index", "type": "uint256"}],
        "name": "getRecord",
        "outputs": [
            {"internalType": "uint256", "name": "", "type": "uint256"},
            {"internalType": "string", "name": "", "type": "string"},
            {"internalType": "string", "name": "", "type": "string"},
            {"internalType": "string", "name": "", "type": "string"}
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getTotalRecords",
        "outputs": [{"internalType": "uint256", "name": "", "type": "uint256"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "owner",
        "outputs": [{"internalType": "address", "name": "", "type": "address"}],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {"internalType": "string", "name": "_sensorId", "type": "string"},
            {"internalType": "string", "name": "_MetricType", "type": "string"},
            {"internalType": "string", "name": "_MetricValue", "type": "string"}
        ],
        "name": "storeData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {"internalType": "string", "name": "_sensorId", "type": "string"},
            {"internalType": "string", "name": "co2", "type": "string"},
            {"internalType": "string", "name": "pm25", "type": "string"},
            {"internalType": "string", "name": "temperature", "type": "string"},
            {"internalType": "string", "name": "humidity", "type": "string"},
            {"internalType": "string", "name": "soilMoisture", "type": "string"},
            {"internalType": "string", "name": "waterPh", "type": "string"},
            {"internalType": "string", "name": "turbidity", "type": "string"}
        ],
        "name": "storeFullSensorData",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    } 
]


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0x1549608d05D5484c8e323a79d721c84EDb92b801

# %%
import time


def send_iot_data(sensor_id, metric_type, metric_value):
    """Sends IoT data to the deployed smart contract"""
    
    print(f"📡 Sending: Sensor={sensor_id}, Type={metric_type}, Value={metric_value}")
    
    txn = contract.functions.storeData(sensor_id, metric_type, metric_value).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
   
    receipt = web3.eth.wait_for_transaction_receipt(txn, timeout=60)
    print(f"✅ Data Stored: {metric_type} - {metric_value}, Txn Hash: {receipt.transactionHash.hex()}")

# %%
metrics = ["co2_ppm", "pm25_ugm3", "temperature_c", "humidity_percent", 
           "soil_moisture_percent", "water_ph", "turbidity_ntu"]

for _, row in df.iterrows():
    sensor_id = str(row["sensor_id"])
    for metric in metrics:
        metric_value = str(row[metric])
        send_iot_data(sensor_id, metric, metric_value)
        time.sleep(1)  # prevent flooding the blockchain
# Out:
# 📡 Sending: Sensor=SENS762, Type=co2_ppm, Value=433.0438194
# ✅ Data Stored: co2_ppm - 433.0438194, Txn Hash: c589f70cce824bd6103f6b27b76175d93ab676ca078dc0eda71eca8210d62c3b
# 📡 Sending: Sensor=SENS762, Type=pm25_ugm3, Value=35.41177588
# ✅ Data Stored: pm25_ugm3 - 35.41177588, Txn Hash: ba57d322fc46db9a053a96774320df600427e451545bda60ee9deaeafc603d2a
# 📡 Sending: Sensor=SENS762, Type=temperature_c, Value=30.7
# ✅ Data Stored: temperature_c - 30.7, Txn Hash: 9246e46bf56c4368e2db0f86b9193a0cf1d0f9bad5946e5a903d4a720fdc3c35
# 📡 Sending: Sensor=SENS762, Type=humidity_percent, Value=64.6
# ✅ Data Stored: humidity_percent - 64.6, Txn Hash: bf919a512d7439da28259c4c0bab57ea9140e034af2675cab2cc3818cec26d22
# 📡 Sending: Sensor=SENS762, Type=soil_moisture_percent, Value=28.8
# ✅ Data Stored: soil_moisture_percent - 28.8, Txn Hash: 76f96d7159dd9927511d5884b9444317e617af0008a4065ec0324af8dee7b0b5
# 📡 Sending: Sensor=SENS762, Type=water_ph, Value=6.88
# ✅ Data Stored: water_ph - 6.88, Txn Hash: 4c08c7ff0d2ce28c1201d75d32fe871048091649156411695be6b86f0330fd5a
# 📡 Sending: Sensor=SENS762, Type=turbidity_ntu, Value=1.82
# ✅ Data Stored: turbidity_ntu - 1.82, Txn Hash: 0a960104dfe93cab297b5f7e9f8c1d11fd15f7f354b6f306cf9543e23f09b129
# 📡 Sending: Sensor=SENS414, Type=co2_ppm, Value=378.758719
# ✅ Data Stored: co2_ppm - 378.758719, Txn Hash: bb55861bb0dc6a138f8e9bae93840c44ad286a84c7fb66e028c5215bc2f8abcc
# 📡 Sending: Sensor=SENS414, Type=pm25_ugm3, Value=19.91283145
# ✅ Data Stored: pm25_ugm3 - 19.91283145, Txn Hash: d08158a56d1e47c292122fa39693ac37e577c17c5e014aa4faab9ec482433eb0
# 📡 Sending: Sensor=SENS414, Type=temperature_c, Value=34.1
# ✅ Data Stored: temperature_c - 34.1, Txn Hash: c412e562b74b84e55a3bee29ba28dcca93655f4d57ebad51c513bbf46908ab0f
# 📡 Sending: Sensor=SENS414, Type=humidity_percent, Value=83.7
# ✅ Data Stored: humidity_percent - 83.7, Txn Hash: 6e4ba45fd66643b293e46d9a2fea2c7e1182e6ebb9a30e03fe91633941e7de30
# 📡 Sending: Sensor=SENS414, Type=soil_moisture_percent, Value=29.3
# ✅ Data Stored: soil_moisture_percent - 29.3, Txn Hash: 1e71dda3255c69447d52c0bf9c87b1934bcb352602818f7e2b2f972827fe358c
# 📡 Sending: Sensor=SENS414, Type=water_ph, Value=8.18
# ✅ Data Stored: water_ph - 8.18, Txn Hash: 0757455ed8acb1b375cf5532297daab3bdb5370cbf9a4ae588dd586dbaba82d5
# 📡 Sending: Sensor=SENS414, Type=turbidity_ntu, Value=4.0
# ✅ Data Stored: turbidity_ntu - 4.0, Txn Hash: 32a703ccc9eacf69b2bdd5604cfb63b30c871b671749b8764182a617cd2b99ab
# 📡 Sending: Sensor=SENS874, Type=co2_ppm, Value=411.6692841
# ✅ Data Stored: co2_ppm - 411.6692841, Txn Hash: 777ed8c507fc6e4d5503215ef2cfb8d3f2c87e8013c8e7b14ee26e25ebff2b68
# 📡 Sending: Sensor=SENS874, Type=pm25_ugm3, Value=39.35696271
# ✅ Data Stored: pm25_ugm3 - 39.35696271, Txn Hash: 7aef3aa9d9e2ef2d76b8aaf8c670795a40dd2b0a451fb0319e8b5f58386ea8bc
# 📡 Sending: Sensor=SENS874, Type=temperature_c, Value=31.2
# ✅ Data Stored: temperature_c - 31.2, Txn Hash: d306f235a20257109deb9f044628cc45b48b998929ebe4b064f404315ead76db
# 📡 Sending: Sensor=SENS874, Type=humidity_percent, Value=85.1
# ✅ Data Stored: humidity_percent - 85.1, Txn Hash: a7f652675a96b9046c316562d29163d8570d55e255fee5ff4eac5c7fc0b7db7a
# 📡 Sending: Sensor=SENS874, Type=soil_moisture_percent, Value=22.7
# ✅ Data Stored: soil_moisture_percent - 22.7, Txn Hash: 953bf513e7b809e31c7ed2405e21b2a1da568cbde0c67241e2031697ddbcf382
# 📡 Sending: Sensor=SENS874, Type=water_ph, Value=6.89
# ✅ Data Stored: water_ph - 6.89, Txn Hash: 51c4378986763dd4cb1e5bf53a1e0edeff9b5107c4d3d8fa7305ed607d8f44db
# 📡 Sending: Sensor=SENS874, Type=turbidity_ntu, Value=1.34
# ✅ Data Stored: turbidity_ntu - 1.34, Txn Hash: 08c34f624f27c6282ea82cd40ebb81123bae009adda7bc61814a74f6bdd54ed4
# 📡 Sending: Sensor=SENS903, Type=co2_ppm, Value=475.8386381
# ✅ Data Stored: co2_ppm - 475.8386381, Txn Hash: ae7e27a10c438cbcc4c5d630fecabc23237bac4dcbf8a601c1828a5e32150849
# 📡 Sending: Sensor=SENS903, Type=pm25_ugm3, Value=29.12629326
# ✅ Data Stored: pm25_ugm3 - 29.12629326, Txn Hash: 7a41415dbc692288a3f11fe0c1ae87e9d9d0fe38a2707428a380676dee59baa3
# 📡 Sending: Sensor=SENS903, Type=temperature_c, Value=28.7
# ✅ Data Stored: temperature_c - 28.7, Txn Hash: 9f0f20c7a895565827371d569458ea8b494976612e7c26cac99820252043da2a
# 📡 Sending: Sensor=SENS903, Type=humidity_percent, Value=76.8
# ✅ Data Stored: humidity_percent - 76.8, Txn Hash: 05d9d63d2bd90a16891962ea174c78e1f38a5a6dad751de7cbe5da2b6e58b149
# 📡 Sending: Sensor=SENS903, Type=soil_moisture_percent, Value=15.6
# ✅ Data Stored: soil_moisture_percent - 15.6, Txn Hash: 48b0f5a61d3b0cfb9f3df3ecb2fa8306512a4282ccae7c2dec7989fdf341165e
# 📡 Sending: Sensor=SENS903, Type=water_ph, Value=7.85
# ✅ Data Stored: water_ph - 7.85, Txn Hash: e2c7355ea8ef138f02290102d0ca1e7bafe3aa3d6f1694857db18d06668566ea
# 📡 Sending: Sensor=SENS903, Type=turbidity_ntu, Value=1.13
# ✅ Data Stored: turbidity_ntu - 1.13, Txn Hash: 8e7a77fd71e8341dcef618153eb15521b1d8cd0a3b58b8ec74431de9f8cbdd65
# 📡 Sending: Sensor=SENS114, Type=co2_ppm, Value=396.2331772
# ✅ Data Stored: co2_ppm - 396.2331772, Txn Hash: 67a501663d7ce1a7a9b060350147a1a8128bb4504a6df17936f3de411ddbcdc7
# 📡 Sending: Sensor=SENS114, Type=pm25_ugm3, Value=40.94845563
# ✅ Data Stored: pm25_ugm3 - 40.94845563, Txn Hash: af90d1f1503963e0134c41ace7c111edd5f1958785ec23d612f1dfe18415d6ec
# 📡 Sending: Sensor=SENS114, Type=temperature_c, Value=32.0
# ✅ Data Stored: temperature_c - 32.0, Txn Hash: 4345334649e52fce6b615742c65d7932ed842ba2584ae7cd587a2145e6badec4
# 📡 Sending: Sensor=SENS114, Type=humidity_percent, Value=81.7
# ✅ Data Stored: humidity_percent - 81.7, Txn Hash: 3f19ffababb98a4ea53bffa2bf0f3ef0a824043e3d564d6e72e7996cf5e7ed8c
# 📡 Sending: Sensor=SENS114, Type=soil_moisture_percent, Value=27.9
# ✅ Data Stored: soil_moisture_percent - 27.9, Txn Hash: 8306a8a2efa7e4a737270ff9eabff9bfa481e2f5f81acdeb2a878eb44d9d7a23
# 📡 Sending: Sensor=SENS114, Type=water_ph, Value=7.73
# ✅ Data Stored: water_ph - 7.73, Txn Hash: 0a407f1727a55ae2d5c01691e4725fc5ee23b03bd0cb1747571272e157df9f75
# 📡 Sending: Sensor=SENS114, Type=turbidity_ntu, Value=0.04
# ✅ Data Stored: turbidity_ntu - 0.04, Txn Hash: 0a397e0c2d36eb24087717b8190dc523c3f4de366a59b572ef11a7afcb59024d
# 📡 Sending: Sensor=SENS115, Type=co2_ppm, Value=409.8621934
# ✅ Data Stored: co2_ppm - 409.8621934, Txn Hash: 2d8076583a5c8e3d45ca1fe2bf302a5b98955a606f1b42ef047aea68da990a7b
# 📡 Sending: Sensor=SENS115, Type=pm25_ugm3, Value=36.93754616
# ✅ Data Stored: pm25_ugm3 - 36.93754616, Txn Hash: bfda1138c84438b6d0cb1bec4a33f07f014ebd7d0de572e378b6e2eb26a1452a
# 📡 Sending: Sensor=SENS115, Type=temperature_c, Value=34.6
# ✅ Data Stored: temperature_c - 34.6, Txn Hash: 3bb4a1a51200ef79f2d3fa727d741916b247752e8de4e14d280e1f4a27bbba2e
# 📡 Sending: Sensor=SENS115, Type=humidity_percent, Value=65.9
# ✅ Data Stored: humidity_percent - 65.9, Txn Hash: 48f0b3e177edc292d7a724f8c5724d5840b2721765ed4159de8bc7f39a8f6f70
# 📡 Sending: Sensor=SENS115, Type=soil_moisture_percent, Value=21.1
# ✅ Data Stored: soil_moisture_percent - 21.1, Txn Hash: 35649dc500a2267eb0df753827df73161418dc8a3f3eca32975f9b6b681726e0
# 📡 Sending: Sensor=SENS115, Type=water_ph, Value=6.76
# ✅ Data Stored: water_ph - 6.76, Txn Hash: c06c7b7c18f64f01ab03924e14bf8d16040ad3317fe4bbb11595b1c2d764e89e
# 📡 Sending: Sensor=SENS115, Type=turbidity_ntu, Value=2.38
# ✅ Data Stored: turbidity_ntu - 2.38, Txn Hash: a151b392fc6aa6e1c86254a5c8a443c5d457f3725d60c95c8f682fb48d48ebfb
# 📡 Sending: Sensor=SENS115, Type=co2_ppm, Value=432.6138979
# ✅ Data Stored: co2_ppm - 432.6138979, Txn Hash: 90b74d13d7ac6cc815d4d14e418ce96d4e494184cc50772c573c4dff8d6fdda2
# 📡 Sending: Sensor=SENS115, Type=pm25_ugm3, Value=18.10419104
# ✅ Data Stored: pm25_ugm3 - 18.10419104, Txn Hash: 57c9b6e5eec7fdf3a37aeaf6f0295804ce55035e9a9c424890ebcc440a9defa1
# 📡 Sending: Sensor=SENS115, Type=temperature_c, Value=29.5
# ✅ Data Stored: temperature_c - 29.5, Txn Hash: 0b79456e0cc0b589ea0af6e648a0b6eb47899dc9bbd690c93fd774eb36c5f2b5
# 📡 Sending: Sensor=SENS115, Type=humidity_percent, Value=51.8
# ✅ Data Stored: humidity_percent - 51.8, Txn Hash: 7a203286a109f38fcd585daffad9b2760d4d1374f04b419abd205976df5bbe03
# 📡 Sending: Sensor=SENS115, Type=soil_moisture_percent, Value=24.6
# ✅ Data Stored: soil_moisture_percent - 24.6, Txn Hash: 09ceb0670babd5a56291f9a101394fa95e9906757cab8ec7c5644326468d2251
# 📡 Sending: Sensor=SENS115, Type=water_ph, Value=6.99
# ✅ Data Stored: water_ph - 6.99, Txn Hash: e14ab849e40a72c3ad167049782456a3a889ac37b292af691db66d049becb787
# 📡 Sending: Sensor=SENS115, Type=turbidity_ntu, Value=4.35
# ✅ Data Stored: turbidity_ntu - 4.35, Txn Hash: 13581907effcf5cf1f8a92cc5c60d89fda29c1a6fdbbbc05afff76354e0b246f
# 📡 Sending: Sensor=SENS478, Type=co2_ppm, Value=438.8756332
# ✅ Data Stored: co2_ppm - 438.8756332, Txn Hash: c8b1dc096b40ddfcdd9a9b21df7a466ef9ee9b1ced35f69eec92f7f278fcf15d
# 📡 Sending: Sensor=SENS478, Type=pm25_ugm3, Value=47.76734479
# ✅ Data Stored: pm25_ugm3 - 47.76734479, Txn Hash: 56d1fcaf6f2455ed66f133c397f03ce43da8064d01138c24b7f03d066174ec9f
# 📡 Sending: Sensor=SENS478, Type=temperature_c, Value=33.8
# ✅ Data Stored: temperature_c - 33.8, Txn Hash: b378cb4b2629578880a15b6ebdf58ac1925a90a8f2ce92367ab8a76553939221
# 📡 Sending: Sensor=SENS478, Type=humidity_percent, Value=51.7
# ✅ Data Stored: humidity_percent - 51.7, Txn Hash: 41472afae1d98110b470ff0510a35dfe788927aeddb07a09b8c9b23ae3d695eb
# 📡 Sending: Sensor=SENS478, Type=soil_moisture_percent, Value=21.6
# ✅ Data Stored: soil_moisture_percent - 21.6, Txn Hash: 1615b74d68bad217b2f7dba88deed908a84ad1099cf5427128d880669bc8ed47
# 📡 Sending: Sensor=SENS478, Type=water_ph, Value=8.33
# ✅ Data Stored: water_ph - 8.33, Txn Hash: c51c9f4cf2acae06b12c3f05e4b7c334ddcc46444d423b337de0c09a0e35f00b
# 📡 Sending: Sensor=SENS478, Type=turbidity_ntu, Value=4.59
# ✅ Data Stored: turbidity_ntu - 4.59, Txn Hash: 186bf3de31005707316df4cf90d43c968b436a2a01e8f3b99cef10de63790a98
# 📡 Sending: Sensor=SENS508, Type=co2_ppm, Value=451.1055378
# ✅ Data Stored: co2_ppm - 451.1055378, Txn Hash: 6aa4643739f7beb5c9ba35a3cbcc9b8286a58c80898edfbc7ec7c6a5306149da
# 📡 Sending: Sensor=SENS508, Type=pm25_ugm3, Value=46.48153514
# ✅ Data Stored: pm25_ugm3 - 46.48153514, Txn Hash: a74f50ffe60eb179d0034e2386e31a78b6a292a01575437bf6f363bb9f8795ca
# 📡 Sending: Sensor=SENS508, Type=temperature_c, Value=33.6
# ✅ Data Stored: temperature_c - 33.6, Txn Hash: 49a8cbd0ae798e406942fcc1da75875336f3588133eb1360b06690225d290e47
# 📡 Sending: Sensor=SENS508, Type=humidity_percent, Value=67.9
# ✅ Data Stored: humidity_percent - 67.9, Txn Hash: 372f64ffe2fee661373e18177f7b6ec402e3afbd35cdc6e2e3ee6b5ec0c97722
# 📡 Sending: Sensor=SENS508, Type=soil_moisture_percent, Value=26.3
# ✅ Data Stored: soil_moisture_percent - 26.3, Txn Hash: c098119fb9923bea93e686b4ff99bfa68fc31475d82f001391012e7bd3100b1b
# 📡 Sending: Sensor=SENS508, Type=water_ph, Value=7.92
# ✅ Data Stored: water_ph - 7.92, Txn Hash: f0af21076e7d2791a43d453ffcee321f0a40f6417761a4c7dc6ca561bda71c4c
# 📡 Sending: Sensor=SENS508, Type=turbidity_ntu, Value=4.15
# ✅ Data Stored: turbidity_ntu - 4.15, Txn Hash: f5a6d2283b2d408ee55155f8a3c02113a60f8c5f70da03246c46e7525604ab23
# 📡 Sending: Sensor=SENS530, Type=co2_ppm, Value=468.575231
# ✅ Data Stored: co2_ppm - 468.575231, Txn Hash: eada1da6f32692bd977926e61cb151c1b398b8d289b4d93f7322480781fd38ca
# 📡 Sending: Sensor=SENS530, Type=pm25_ugm3, Value=33.37992328
# ✅ Data Stored: pm25_ugm3 - 33.37992328, Txn Hash: 0fcf0b142f330771f64a7aa12b2b505ad83dc7c812cbca7ddc8d3e1a5db5d556
# 📡 Sending: Sensor=SENS530, Type=temperature_c, Value=28.1
# ✅ Data Stored: temperature_c - 28.1, Txn Hash: a54b2ad17ee0c0ace4fd97e10feaf9bc23e6e8b5d1217b7fcb9bc0f278978508
# 📡 Sending: Sensor=SENS530, Type=humidity_percent, Value=87.4
# ✅ Data Stored: humidity_percent - 87.4, Txn Hash: a24cbb51f33fe1e6088a0e0b4ffb0bd9b79a5140994855bede4dbac0a7e0f6b4
# 📡 Sending: Sensor=SENS530, Type=soil_moisture_percent, Value=19.3
# ✅ Data Stored: soil_moisture_percent - 19.3, Txn Hash: 030ba4d1aa4bb46d116dce5cba8498dc8e8380e10f36eb62f2e6b4625367f4e0
# 📡 Sending: Sensor=SENS530, Type=water_ph, Value=7.12
# ✅ Data Stored: water_ph - 7.12, Txn Hash: de8e7d59a7726ef801eef3cb438fffd1592ba9faffee4a9cca342e993cc61562
# 📡 Sending: Sensor=SENS530, Type=turbidity_ntu, Value=1.81
# ✅ Data Stored: turbidity_ntu - 1.81, Txn Hash: f066372c4cb76ec507aad2dfbefc054c175fa2aa35704d9a8516aba09db78d66
# 📡 Sending: Sensor=SENS559, Type=co2_ppm, Value=411.7417807
# ✅ Data Stored: co2_ppm - 411.7417807, Txn Hash: eb2462ab905f0df682ec22e5f0bbc1cf10a308f9ab0fd50923f2da070781c009
# 📡 Sending: Sensor=SENS559, Type=pm25_ugm3, Value=22.04393202
# ✅ Data Stored: pm25_ugm3 - 22.04393202, Txn Hash: 3e88d0517ac5044d163272105803646e0dafbf8d2b364cb7987af5e62d2b8b70
# 📡 Sending: Sensor=SENS559, Type=temperature_c, Value=33.5
# ✅ Data Stored: temperature_c - 33.5, Txn Hash: a2fe87fc19475d38b4ffdd46349abcf2186001d0299b469fd3da6c97f8ef0210
# 📡 Sending: Sensor=SENS559, Type=humidity_percent, Value=85.0
# ✅ Data Stored: humidity_percent - 85.0, Txn Hash: 0482bc773ea347c3d03fe78a829bf70fea6cb6ce03b20f2acc314040dc08cf1c
# 📡 Sending: Sensor=SENS559, Type=soil_moisture_percent, Value=24.2
# ✅ Data Stored: soil_moisture_percent - 24.2, Txn Hash: 3196915f12bbde2f618ed627824b46f807d35c8884c83cb097d3a1aad0188dd6
# 📡 Sending: Sensor=SENS559, Type=water_ph, Value=6.8
# ✅ Data Stored: water_ph - 6.8, Txn Hash: 02d7016e1b2c84f3b95b25079933b86829b44475e07040de544b974e340e106a
# 📡 Sending: Sensor=SENS559, Type=turbidity_ntu, Value=2.93
# ✅ Data Stored: turbidity_ntu - 2.93, Txn Hash: 78f3c78a3b80d7d1756ecd3db3ff0d5d8fdf78db817331795989159bd779a8da
# 📡 Sending: Sensor=SENS981, Type=co2_ppm, Value=409.2211895
# ✅ Data Stored: co2_ppm - 409.2211895, Txn Hash: 4a4f6e1a8b9e8a98d6936edc6873ac9f3fbd6c9c1742901106ccc027f40ef1fd
# 📡 Sending: Sensor=SENS981, Type=pm25_ugm3, Value=50.09176869
# ✅ Data Stored: pm25_ugm3 - 50.09176869, Txn Hash: 004ba93e05b917fe9bccc7f5d8beedafc4d48cf5d94493fc1383023b84bd6f87
# 📡 Sending: Sensor=SENS981, Type=temperature_c, Value=28.7
# ✅ Data Stored: temperature_c - 28.7, Txn Hash: 6060c91fe91bb6fe09876e31845d4552cfc8fac3bb03e551f399f5363dcfd071
# 📡 Sending: Sensor=SENS981, Type=humidity_percent, Value=54.9
# ✅ Data Stored: humidity_percent - 54.9, Txn Hash: a850667fb34ec76be7a125d6ede597aa21db783266822f6d096ca8b7b5bea2e2
# 📡 Sending: Sensor=SENS981, Type=soil_moisture_percent, Value=12.0
# ✅ Data Stored: soil_moisture_percent - 12.0, Txn Hash: 84203fd4bb6f582375fcd93c3ec2ff8a6e5edc3ef537b662712c7e69b72a70af
# 📡 Sending: Sensor=SENS981, Type=water_ph, Value=7.84
# ✅ Data Stored: water_ph - 7.84, Txn Hash: 7d3279bc37e88510cff6b69c6ccb93c94d0336141770adf14e15c53cd2022d9e
# 📡 Sending: Sensor=SENS981, Type=turbidity_ntu, Value=2.54
# ✅ Data Stored: turbidity_ntu - 2.54, Txn Hash: af98070b2d9925ba7cf4fced9e6fb5cb4f9bd161c92b850405f4983b59a2248c
# 📡 Sending: Sensor=SENS235, Type=co2_ppm, Value=403.7092439
# ✅ Data Stored: co2_ppm - 403.7092439, Txn Hash: 0f1e56b523322e3b8e579d6eaa1eed573913064d5d077ec5b438579ae5540c77
# 📡 Sending: Sensor=SENS235, Type=pm25_ugm3, Value=40.17179296
# ✅ Data Stored: pm25_ugm3 - 40.17179296, Txn Hash: 22268825a797c97d4605920fd063c30840728ca2493994c40a1e1994066087ba
# 📡 Sending: Sensor=SENS235, Type=temperature_c, Value=27.6
# ✅ Data Stored: temperature_c - 27.6, Txn Hash: 2da6ce2cb8f52e12ad375810ed85a2171c5c47b14ba667cc888ff47ac18f9921
# 📡 Sending: Sensor=SENS235, Type=humidity_percent, Value=84.8
# ✅ Data Stored: humidity_percent - 84.8, Txn Hash: f9b1b873b24c7f10dd8e61131198ed240637be2e04934792f90127d9ca17d1a0
# 📡 Sending: Sensor=SENS235, Type=soil_moisture_percent, Value=10.5
# ✅ Data Stored: soil_moisture_percent - 10.5, Txn Hash: 5fac132384bd4c948c3fe49f281bdf896d256de13f4ee1deadbaae6ef969153b
# 📡 Sending: Sensor=SENS235, Type=water_ph, Value=7.49
# ✅ Data Stored: water_ph - 7.49, Txn Hash: 892c83b84fd62481de16053de7ff5769e30131399d4b829cc4621bc05796c0c0
# 📡 Sending: Sensor=SENS235, Type=turbidity_ntu, Value=1.37
# ✅ Data Stored: turbidity_ntu - 1.37, Txn Hash: a0a656e871c7afb5b8454e8380a79a9432cd8ba9a33a46478ff87d678936303b
# 📡 Sending: Sensor=SENS153, Type=co2_ppm, Value=434.2496993
# ✅ Data Stored: co2_ppm - 434.2496993, Txn Hash: 62772e6dee29886da8bad50a67d30d36a2ca2b6121319e179748e0b281130b4e
# 📡 Sending: Sensor=SENS153, Type=pm25_ugm3, Value=44.50604366
# ✅ Data Stored: pm25_ugm3 - 44.50604366, Txn Hash: 1da4414741477f472c30fc51d08e50a26d9a757240bfd1c716b95dcc59b99824
# 📡 Sending: Sensor=SENS153, Type=temperature_c, Value=29.5
# ✅ Data Stored: temperature_c - 29.5, Txn Hash: 7945fc5a3c28fdc4ae2877610425d5c1ba374c35065e26c0e99aa9e3671bffec
# 📡 Sending: Sensor=SENS153, Type=humidity_percent, Value=69.7
# ✅ Data Stored: humidity_percent - 69.7, Txn Hash: 7b049d689a9c94d8502e45e1444b414d30d06493b65b24f9f151eb794f93dbfe
# 📡 Sending: Sensor=SENS153, Type=soil_moisture_percent, Value=19.8
# ✅ Data Stored: soil_moisture_percent - 19.8, Txn Hash: 4d62202502c05d7c6949648dbf772f5a88b60f8a39f8b21ed19862351d79a7f8
# 📡 Sending: Sensor=SENS153, Type=water_ph, Value=8.14
# ✅ Data Stored: water_ph - 8.14, Txn Hash: 21227c3ca79c5ed38deb1727adeaa800a41c723dff6da350f204db8457711faf
# 📡 Sending: Sensor=SENS153, Type=turbidity_ntu, Value=2.92
# ✅ Data Stored: turbidity_ntu - 2.92, Txn Hash: 07ff112fb59543c0809ab3836c1d617fa63373d2c8c047be92315e5f778366f1
# 📡 Sending: Sensor=SENS425, Type=co2_ppm, Value=424.7340591
# ✅ Data Stored: co2_ppm - 424.7340591, Txn Hash: ecddfb37f144afd3785cc9f754e9e1adf7612861d5d12348a725397910eb520d
# 📡 Sending: Sensor=SENS425, Type=pm25_ugm3, Value=21.44371855
# ---------------------------------------------------------------------------
# Web3RPCError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5900\693846386.py in <module>
#       6     for metric in metrics:
#       7         metric_value = str(row[metric])
# ----> 8         send_iot_data(sensor_id, metric, metric_value)
#       9         time.sleep(1)  # prevent flooding the blockchain
#
# ~\AppData\Local\Temp\ipykernel_5900\3708642229.py in send_iot_data(sensor_id, metric_type, metric_value)
#       7     print(f"📡 Sending: Sensor={sensor_id}, Type={metric_type}, Value={metric_value}")
#       8
# ----> 9     txn = contract.functions.storeData(sensor_id, metric_type, metric_value).transact({
#      10         'from': web3.eth.default_account,
#      11         'gas': 3000000
#
# ~\anaconda3\lib\site-packages\web3\contract\contract.py in transact(self, transaction)
#     309         abi_element_identifier = abi_to_signature(self.abi)
#     310
# --> 311         return transact_with_contract_function(
#     312             self.address,
#     313             self.w3,
#
# ~\anaconda3\lib\site-packages\web3\contract\utils.py in transact_with_contract_function(address, w3, abi_element_identifier, transaction, contract_abi, fn_abi, *args, **kwargs)
#     263     )
#     264
# --> 265     txn_hash = w3.eth.send_transaction(transact_transaction)
#     266     return txn_hash
#     267
#
# ~\anaconda3\lib\site-packages\web3\eth\eth.py in send_transaction(self, transaction)
#     385
#     386     def send_transaction(self, transaction: TxParams) -> HexBytes:
# --> 387         return self._send_transaction(transaction)
#     388
#     389     # eth_sendRawTransaction
#
# ~\anaconda3\lib\site-packages\web3\module.py in caller(*args, **kwargs)
#     110             null_result_formatters,
#     111         ) = response_formatters
# --> 112         result = w3.manager.request_blocking(
#     113             method_str, params, error_formatters, null_result_formatters
#     114         )
#
# ~\anaconda3\lib\site-packages\web3\manager.py in request_blocking(self, method, params, error_formatters, null_result_formatters)
#     230         """
#     231         response = self._make_request(method, params)
# --> 232         return self.formatted_response(
#     233             response, params, error_formatters, null_result_formatters
#     234         )
#
# ~\anaconda3\lib\site-packages\web3\manager.py in formatted_response(self, response, params, error_formatters, null_result_formatters)
#     196         )
#     197
# --> 198         validate_rpc_response_and_raise_if_error(
#     199             response,
#     200             error_formatters,
#
# ~\anaconda3\lib\site-packages\web3\_utils\validation.py in validate_rpc_response_and_raise_if_error(response, error_formatters, is_subscription_response, logger, params)
#     399             logger.debug("RPC error response: %s", response)
#     400
# --> 401         raise web3_rpc_error
#     402
#     403     elif "result" not in response and not is_subscription_response:
#
# Web3RPCError: {'message': 'VM Exception while processing transaction: revert Storage limit reached', 'stack': 'RuntimeError: VM Exception while processing transaction: revert Storage limit reached\n    at EIP1559FeeMarketTransaction.fillFromResult (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:12745)\n    at Miner.<anonymous> (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:36703)\n    at async Miner.<anonymous> (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:35116)\n    at async Miner.mine (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:39680)\n    at async Blockchain.mine (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\dist\\node\\1.js:2:60063)\n    at async Promise.all (index 0)\n    at async TransactionPool.emit (C:\\Program Files\\WindowsApps\\GanacheUI_2.7.1.0_x64__rb4352f0jd4m2\\app\\resources\\static\\node\\node_modules\\ganache\\node_modules\\emittery\\index.js:303:3)', 'code': -32000, 'name': 'RuntimeError', 'data': {'hash': '0x7d213901512f9cb7061766c7bff8aa737c3aee0e6df65762a1c17d8a0417d908', 'programCounter': 1769, 'result': '0x7d213901512f9cb7061766c7bff8aa737c3aee0e6df65762a1c17d8a0417d908', 'reason': 'Storage limit reached', 'message': 'revert'}}

# %%
# Get total stored records
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 100

# %%
# Retrieve and print a specific record 

record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# First Stored Record: [1747997549, 'TEST001', 'Temperature', '22.5°C']
